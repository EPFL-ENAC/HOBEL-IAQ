# %%
import pandas as pd

# %%
DATA_FOLDER = '/Users/bdu/Library/CloudStorage/OneDrive-SharedLibraries-epfl.ch/ENAC-IT - Pilot_iAQ_Shared/Data'

# %%
import os
pd.read_csv(os.path.join(DATA_FOLDER,'data_COA_13130304.csv'))
# Out:
#      Unnamed: 0 13130304_COA_CAS  13130304_COA_Name_list  \
# 0             1         100-41-4           Ethyl Benzene
# 1             2         100-42-5                 Styrene
# 2             3         100-44-7         Benzyl Chloride
# 3             4         100-51-6          Benzyl Alcohol
# 4             5         103-65-1          Propyl Benzene
# ..          ...              ...                     ...
# 200         201         565-75-3  2,3,4-Trimethylpentane
# 201         202         107-01-7                2-butene
# 202         203         560-21-4  2,3,3-Trimethylpentane
# 203         204         584-94-1      2,3-Dimethylhexane
# 204         205  100-100-100-100       Total(As Toluene)
#
#     13130304_COA_Name_file  13130304_COA_R.time  13130304_COA_ppb  \
# 0                      NaN                  NaN               NaN
# 1                      NaN                  NaN               NaN
# 2                      NaN                  NaN               NaN
# ...
